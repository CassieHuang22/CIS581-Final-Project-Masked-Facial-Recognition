# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "/content/drive/MyDrive/Colab Notebooks/CIS-5810/Project/Masks"
# Out:
# /content/drive/MyDrive/Colab Notebooks/CIS-5810/Project/Masks

# %%
# !git clone https://github.com/aqeelanwar/MaskTheFace.git
# Out:
# fatal: destination path 'MaskTheFace' already exists and is not an empty directory.

# %%
import torchvision

# %%
lfw_train = torchvision.datasets.LFWPairs(".", split='train', download=True)
lfw_test = torchvision.datasets.LFWPairs(".", split='test', download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# !pip install -r MaskTheFace/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
cd MaskTheFace/
# Out:
# [Errno 2] No such file or directory: 'MaskTheFace/'
# /content/drive/MyDrive/Colab Notebooks/CIS-5810/Project/Masks/MaskTheFace

# %%
# !python mask_the_face.py --path ../lfw-py/lfw_funneled/ --mask_type 'KN95' --verbose --color '#808080'
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0001.jpg
# Faces found:  1
#  76% 4390/5749 [17:13<02:25,  9.37it/s][0.]
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0002.jpg
# Faces found:  1
#  76% 4390/5749 [17:13<02:25,  9.37it/s][0.]
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0003.jpg
# Faces found:  1
#  76% 4390/5749 [17:13<02:25,  9.37it/s][0.]
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0004.jpg
# Faces found:  1
#  76% 4390/5749 [17:13<02:25,  9.37it/s][0.]
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0005.jpg
# Faces found:  1
#  76% 4390/5749 [17:13<02:25,  9.37it/s][0.]
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0006.jpg
# Faces found:  1
#  76% 4390/5749 [17:13<02:25,  9.37it/s][0.]
# Processing: ../lfw-py/lfw_funneled//Gunter_Pleuger/Gunter_Pleuger_0007.jpg
# Faces found:  1
# ...
